# %% [markdown]
# # Bike Sharing Demond Prediction

# %%
import pandas as pd
d=pd.read_csv("C:/Users/Shree/OneDrive/Desktop/Bike Data.csv",encoding='latin1')
d
# Out:
#             Date  Rented Bike Count  Hour  Temperature(øC)  Humidity(%)  \
# 0     01-12-2017                254     0             -5.2           37
# 1     01-12-2017                204     1             -5.5           38
# 2     01-12-2017                173     2             -6.0           39
# 3     01-12-2017                107     3             -6.2           40
# 4     01-12-2017                 78     4             -6.0           36
# ...          ...                ...   ...              ...          ...
# 8755  30-11-2018               1003    19              4.2           34
# 8756  30-11-2018                764    20              3.4           37
# 8757  30-11-2018                694    21              2.6           39
# 8758  30-11-2018                712    22              2.1           41
# 8759  30-11-2018                584    23              1.9           43
#
#       Wind speed (m/s)  Visibility (10m)  Dew point temperature(øC)  \
# ...

# %% [markdown]
# # Data Preprocessing

# %%
mv= d.isnull().sum()
mv
# Out:
# Date                         0
# Rented Bike Count            0
# Hour                         0
# Temperature(øC)              0
# Humidity(%)                  0
# Wind speed (m/s)             0
# Visibility (10m)             0
# Dew point temperature(øC)    0
# Solar Radiation (MJ/m2)      0
# Rainfall(mm)                 0
# Snowfall (cm)                0
# Seasons                      0
# Holiday                      0
# Functioning Day              0
# dtype: int64

# %%
df=pd.DataFrame(d)
df
# Out:
#             Date  Rented Bike Count  Hour  Temperature(øC)  Humidity(%)  \
# 0     01-12-2017                254     0             -5.2           37
# 1     01-12-2017                204     1             -5.5           38
# 2     01-12-2017                173     2             -6.0           39
# 3     01-12-2017                107     3             -6.2           40
# 4     01-12-2017                 78     4             -6.0           36
# ...          ...                ...   ...              ...          ...
# 8755  30-11-2018               1003    19              4.2           34
# 8756  30-11-2018                764    20              3.4           37
# 8757  30-11-2018                694    21              2.6           39
# 8758  30-11-2018                712    22              2.1           41
# 8759  30-11-2018                584    23              1.9           43
#
#       Wind speed (m/s)  Visibility (10m)  Dew point temperature(øC)  \
# ...

# %%
df["Date"]=pd.to_datetime(df["Date"],format="mixed")
df
# Out:
#            Date  Rented Bike Count  Hour  Temperature(øC)  Humidity(%)  \
# 0    2017-01-12                254     0             -5.2           37
# 1    2017-01-12                204     1             -5.5           38
# 2    2017-01-12                173     2             -6.0           39
# 3    2017-01-12                107     3             -6.2           40
# 4    2017-01-12                 78     4             -6.0           36
# ...         ...                ...   ...              ...          ...
# 8755 2018-11-30               1003    19              4.2           34
# 8756 2018-11-30                764    20              3.4           37
# 8757 2018-11-30                694    21              2.6           39
# 8758 2018-11-30                712    22              2.1           41
# 8759 2018-11-30                584    23              1.9           43
#
#       Wind speed (m/s)  Visibility (10m)  Dew point temperature(øC)  \
# ...

# %%
df["Day"]=df["Date"].dt.day
df["Month"]=df["Date"].dt.month
df["Year"]=df["Date"].dt.year

# %%
df
# Out:
#            Date  Rented Bike Count  Hour  Temperature(øC)  Humidity(%)  \
# 0    2017-01-12                254     0             -5.2           37
# 1    2017-01-12                204     1             -5.5           38
# 2    2017-01-12                173     2             -6.0           39
# 3    2017-01-12                107     3             -6.2           40
# 4    2017-01-12                 78     4             -6.0           36
# ...         ...                ...   ...              ...          ...
# 8755 2018-11-30               1003    19              4.2           34
# 8756 2018-11-30                764    20              3.4           37
# 8757 2018-11-30                694    21              2.6           39
# 8758 2018-11-30                712    22              2.1           41
# 8759 2018-11-30                584    23              1.9           43
#
#       Wind speed (m/s)  Visibility (10m)  Dew point temperature(øC)  \
# ...

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 8760 entries, 0 to 8759
# Data columns (total 17 columns):
#  #   Column                     Non-Null Count  Dtype
# ---  ------                     --------------  -----
#  0   Date                       8760 non-null   datetime64[ns]
#  1   Rented Bike Count          8760 non-null   int64
#  2   Hour                       8760 non-null   int64
#  3   Temperature(øC)            8760 non-null   float64
#  4   Humidity(%)                8760 non-null   int64
#  5   Wind speed (m/s)           8760 non-null   float64
#  6   Visibility (10m)           8760 non-null   int64
#  7   Dew point temperature(øC)  8760 non-null   float64
#  8   Solar Radiation (MJ/m2)    8760 non-null   float64
#  9   Rainfall(mm)               8760 non-null   float64
#  10  Snowfall (cm)              8760 non-null   float64
#  11  Seasons                    8760 non-null   object
#  12  Holiday                    8760 non-null   object
# ...

# %%
c=df.drop("Date",axis=1)
c
# Out:
#       Rented Bike Count  Hour  Temperature(øC)  Humidity(%)  Wind speed (m/s)  \
# 0                   254     0             -5.2           37               2.2
# 1                   204     1             -5.5           38               0.8
# 2                   173     2             -6.0           39               1.0
# 3                   107     3             -6.2           40               0.9
# 4                    78     4             -6.0           36               2.3
# ...                 ...   ...              ...          ...               ...
# 8755               1003    19              4.2           34               2.6
# 8756                764    20              3.4           37               2.3
# 8757                694    21              2.6           39               0.3
# 8758                712    22              2.1           41               1.0
# 8759                584    23              1.9           43               1.3
#
# ...

# %%
c.head()
# Out:
#    Rented Bike Count  Hour  Temperature(øC)  Humidity(%)  Wind speed (m/s)  \
# 0                254     0             -5.2           37               2.2
# 1                204     1             -5.5           38               0.8
# 2                173     2             -6.0           39               1.0
# 3                107     3             -6.2           40               0.9
# 4                 78     4             -6.0           36               2.3
#
#    Visibility (10m)  Dew point temperature(øC)  Solar Radiation (MJ/m2)  \
# 0              2000                      -17.6                      0.0
# 1              2000                      -17.6                      0.0
# 2              2000                      -17.7                      0.0
# 3              2000                      -17.6                      0.0
# 4              2000                      -18.6                      0.0
#
#    Rainfall(mm)  Snowfall (cm) Seasons     Holiday Functioning Day  Day  \
# ...

# %%
from sklearn.preprocessing import LabelEncoder
import pandas as pd
label_encoder= LabelEncoder()
c["Seasons"]=label_encoder.fit_transform(c["Seasons"])
c["Holiday"] =label_encoder.fit_transform(c["Holiday"])
c["Functioning Day"] = label_encoder.fit_transform(c["Functioning Day"])
print("c")
p=pd.DataFrame(c)
p
# Out:
# c
#       Rented Bike Count  Hour  Temperature(øC)  Humidity(%)  Wind speed (m/s)  \
# 0                   254     0             -5.2           37               2.2
# 1                   204     1             -5.5           38               0.8
# 2                   173     2             -6.0           39               1.0
# 3                   107     3             -6.2           40               0.9
# 4                    78     4             -6.0           36               2.3
# ...                 ...   ...              ...          ...               ...
# 8755               1003    19              4.2           34               2.6
# 8756                764    20              3.4           37               2.3
# 8757                694    21              2.6           39               0.3
# 8758                712    22              2.1           41               1.0
# 8759                584    23              1.9           43               1.3
#
# ...

# %% [markdown]
# # Visualisation

# %%
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
plt.figure(figsize=(6,4))
sns.barplot(x="Holiday",y="Rented Bike Count",data=d)
# Out:
# <Axes: xlabel='Holiday', ylabel='Rented Bike Count'>

# %% [markdown]
# Interpretation: The Average Rented Bike count is more at non holiday as compared to holiday.

# %%
month=p.groupby("Month").sum().reset_index()
month
# Out:
#     Month  Rented Bike Count  Hour  Temperature(øC)  Humidity(%)  \
# 0       1             287244  8556           2025.8        39381
# 1       2             264112  7728           4357.5        34800
# 2       3             455037  8556           8508.9        44513
# 3       4             556219  8280           9872.1        38614
# 4       5             665948  8556          12365.5        45191
# 5       6             706728  8280          13678.7        47259
# 6       7             691339  8556          17205.3        45076
# 7       8             614190  8556          15816.8        46871
# 8       9             499326  8280          12291.7        43756
# 9      10             626988  8556           9008.3        44629
# 10     11             493412  8280           5606.8        38670
# 11     12             311771  8556           2117.0        41302
#
#     Wind speed (m/s)  Visibility (10m)  Dew point temperature(øC)  \
# ...

# %%
import pandas as pd
import calendar
df1=pd.DataFrame(p)
def month_to_name(number):
    return calendar.month_name[number]
df1["month_name"]=df1["Month"].apply(month_to_name)
df1
# Out:
#       Rented Bike Count  Hour  Temperature(øC)  Humidity(%)  Wind speed (m/s)  \
# 0                   254     0             -5.2           37               2.2
# 1                   204     1             -5.5           38               0.8
# 2                   173     2             -6.0           39               1.0
# 3                   107     3             -6.2           40               0.9
# 4                    78     4             -6.0           36               2.3
# ...                 ...   ...              ...          ...               ...
# 8755               1003    19              4.2           34               2.6
# 8756                764    20              3.4           37               2.3
# 8757                694    21              2.6           39               0.3
# 8758                712    22              2.1           41               1.0
# 8759                584    23              1.9           43               1.3
#
# ...

# %%
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
plt.Figure(figsize=(17,8))
sns.barplot(x="month_name",y="Rented Bike Count",data=df1)
# Out:
# <Axes: xlabel='month_name', ylabel='Rented Bike Count'>

# %% [markdown]
# Interpretation:Plot shows in month June and July the Average count of Rented Bike is more than Other Months.

# %%
plt.Figure(figsize=(6,4))
sns.barplot(x="Day",y="Rented Bike Count",data=p)
# Out:
# <Axes: xlabel='Day', ylabel='Rented Bike Count'>

# %% [markdown]
# Interpretation:At the starting of the month from date 6 to 9 demand of Average rented bike is high ,also from date 13 to 31 demand is high
# but at starting of month there is no high demand for the average rented bike.

# %%
plt.Figure(figsize=(6,4))
sns.barplot(x="Hour",y="Rented Bike Count",data=d)
# Out:
# <Axes: xlabel='Hour', ylabel='Rented Bike Count'>

# %% [markdown]
# Interpretation:Maximum Number of the average Bikes Rented are  18 Hour and Minimum Number of the average Bikes Are Rented for 4 Hour

# %%
 plt.Figure(figsize=(14,8))
sns.catplot(data=d,x="Hour",y="Rented Bike Count",hue='Holiday',kind='bar',height=6,aspect=1.5)
plt.title('Rented Bike Count By Hour and holoday')
plt.show()

# %% [markdown]
# #Interpretation:The Average of rented bike count is more at non holiday as compared to holiday. Maximum Number of the average Bikes Rented are 18 Hour
# and Minimum Number of the average Bikes Are Rented for 4 Hour.

# %%
import matplotlib.pyplot as plt
plt.Figure(figsize=(6,4))
sns.barplot(x="Seasons",y="Rented Bike Count",data=d)
# Out:
# <Axes: xlabel='Seasons', ylabel='Rented Bike Count'>

# %% [markdown]
# Interpretation:the average Rented Bike count is more in summer seasons as compare to other seasons.

# %%
plt.Figure(figsize=(6,4))
sns.barplot(x="Year",y="Rented Bike Count",data=p)
# Out:
# <Axes: xlabel='Year', ylabel='Rented Bike Count'>

# %% [markdown]
# Interpretation:The average Rented Bike count is more in year 2018 than 2017.

# %%
plt.Figure(figsize=(6,4))
sns.regplot(x=p["Temperature(øC)"],y=p["Rented Bike Count"])
plt.show()

# %%
Interpretation:As Temperature increases the average Rented Bike count also increases.

# %%
plt.Figure(figsize=(6,4))
sns.regplot(x=p["Humidity(%)"],y=p["Rented Bike Count"])
plt.show()

# %% [markdown]
# Interpretation:As Humidity increases the average  rented bikes decreases.

# %%
plt.Figure(figsize=(14,8))
sns.catplot(data=d,x="Seasons",y="Rented Bike Count",hue='Holiday',kind='bar',height=6,aspect=1.5)
plt.title('Rented Bike Count By season and holoday')
plt.show()

# %% [markdown]
# Interpretation:In summer season the average of rented bike is more as compare to other season and also when there is no Holiday and
# also for holiday the demand is more for rented bike in summer season.

# %%
d.describe()
# Out:
#        Rented Bike Count         Hour  Temperature(øC)  Humidity(%)  \
# count        8760.000000  8760.000000      8760.000000  8760.000000
# mean          704.602055    11.500000        12.882922    58.226256
# std           644.997468     6.922582        11.944825    20.362413
# min             0.000000     0.000000       -17.800000     0.000000
# 25%           191.000000     5.750000         3.500000    42.000000
# 50%           504.500000    11.500000        13.700000    57.000000
# 75%          1065.250000    17.250000        22.500000    74.000000
# max          3556.000000    23.000000        39.400000    98.000000
#
#        Wind speed (m/s)  Visibility (10m)  Dew point temperature(øC)  \
# count       8760.000000       8760.000000                8760.000000
# mean           1.724909       1436.825799                   4.073813
# std            1.036300        608.298712                  13.060369
# min            0.000000         27.000000                 -30.600000
# ...

# %%
q1=p["Rented Bike Count"].quantile(0.25)
q3=p["Rented Bike Count"].quantile(0.75)
iqr=q3-q1

# %%
q1,q3,iqr
# Out:
# (191.0, 1065.25, 874.25)

# %%
upper_limit=q3+(1.5*iqr)
lower_limit=q1-(1.5*iqr)
lower_limit,upper_limit
# Out:
# (-1120.375, 2376.625)

# %%
new_data=p.loc[(p["Rented Bike Count"]<upper_limit)&(p["Rented Bike Count"]>lower_limit)]
print('before removing outliers:',len(p))
print('after removing outliers:',len(new_data))
print('outliers:',len(p)-len(new_data))
# Out:
# before removing outliers: 8760
# after removing outliers: 8602
# outliers: 158

# %%
q1=new_data["Solar Radiation (MJ/m2)"].quantile(0.25)
q3=new_data["Solar Radiation (MJ/m2)"].quantile(0.75)
iqr=q3-q1

# %%
q1,q3,iqr
# Out:
# (0.0, 0.93, 0.93)

# %%
upper_limit=q3+(1.5*iqr)
lower_limit=q1-(1.5*iqr)
lower_limit,upper_limit
# Out:
# (-1.395, 2.325)

# %%
new_data1=new_data.loc[(new_data["Solar Radiation (MJ/m2)"]<upper_limit)&(new_data["Solar Radiation (MJ/m2)"]>lower_limit)]
print('before removing outliers:',len(new_data))
print('after removing outliers:',len(new_data1))
print('outliers:',len(new_data)-len(new_data1))
# Out:
# before removing outliers: 8602
# after removing outliers: 7962
# outliers: 640

# %%
incontrol=new_data1[(new_data1["Rainfall(mm)"]>(3*0.15*1.13))|(new_data1["Rainfall(mm)"]<-(3*0.15*1.13))]
o=pd.DataFrame(incontrol)
o
# Out:
#       Rented Bike Count  Hour  Temperature(øC)  Humidity(%)  Wind speed (m/s)  \
# 54                   13     6              3.4           86               2.5
# 57                  152     9              3.5           91               1.8
# 141                 165    21              1.1           92               0.5
# 222                   9     6             -0.5           90               0.9
# 225                  31     9              0.2           90               1.0
# ...                 ...   ...              ...          ...               ...
# 8229                 21    21             14.0           96               4.1
# 8232                  0     0             12.0           96               3.1
# 8523                112     3              6.5           87               1.0
# 8601                 24     9              0.3           97               3.0
# 8604                167    12              2.5           84               1.9
#
# ...

# %%
index=o.index.tolist()
index
# Out:
# [54,
#  57,
#  141,
#  222,
#  225,
#  417,
#  420,
#  561,
#  564,
#  567,
#  723,
#  933,
#  1266,
#  1458,
#  1461,
#  2019,
#  2151,
#  2154,
#  2157,
#  2160,
#  2253,
#  2256,
#  2259,
#  2262,
#  2331,
#  2334,
#  2502,
#  2505,
#  2508,
#  2978,
#  2979,
#  2980,
#  2981,
#  2982,
#  3007,
#  3008,
#  3016,
#  3017,
#  3019,
#  3021,
#  3026,
#  3027,
#  3028,
#  3090,
#  3091,
#  3142,
#  3143,
#  3220,
#  3222,
#  3223,
#  3224,
#  3225,
#  3226,
#  3425,
#  3428,
#  3429,
#  3430,
#  3431,
#  3432,
#  3434,
#  3436,
#  3437,
#  3438,
#  3439,
#  3440,
#  3441,
#  3442,
#  3443,
#  3444,
#  3445,
#  3446,
#  3447,
#  3448,
#  3450,
#  3451,
#  3452,
#  3453,
#  3459,
#  3655,
#  3660,
#  3661,
#  3669,
#  3671,
#  3747,
#  3748,
#  3749,
#  3750,
#  3751,
#  3752,
#  3753,
#  3754,
#  3755,
#  3756,
#  3896,
#  3897,
#  3898,
#  3899,
#  3900,
#  3901,
#  3902,
#  3903,
#  3904,
#  3905,
#  3906,
#  3907,
#  3908,
#  3910,
#  3911,
#  3987,
#  3990,
#  3993,
#  3994,
# ...

# %%
final_data=new_data1.drop(index)
final_data
# Out:
#       Rented Bike Count  Hour  Temperature(øC)  Humidity(%)  Wind speed (m/s)  \
# 0                   254     0             -5.2           37               2.2
# 1                   204     1             -5.5           38               0.8
# 2                   173     2             -6.0           39               1.0
# 3                   107     3             -6.2           40               0.9
# 4                    78     4             -6.0           36               2.3
# ...                 ...   ...              ...          ...               ...
# 8755               1003    19              4.2           34               2.6
# 8756                764    20              3.4           37               2.3
# 8757                694    21              2.6           39               0.3
# 8758                712    22              2.1           41               1.0
# 8759                584    23              1.9           43               1.3
#
# ...

# %%
x=final_data.drop(columns=['Rented Bike Count'],axis=1)
x
# Out:
#       Hour  Temperature(øC)  Humidity(%)  Wind speed (m/s)  Visibility (10m)  \
# 0        0             -5.2           37               2.2              2000
# 1        1             -5.5           38               0.8              2000
# 2        2             -6.0           39               1.0              2000
# 3        3             -6.2           40               0.9              2000
# 4        4             -6.0           36               2.3              2000
# ...    ...              ...          ...               ...               ...
# 8755    19              4.2           34               2.6              1894
# 8756    20              3.4           37               2.3              2000
# 8757    21              2.6           39               0.3              1968
# 8758    22              2.1           41               1.0              1859
# 8759    23              1.9           43               1.3              1909
#
# ...

# %%
final_data=new_data1.drop(index)
final_data
# Out:
#       Rented Bike Count  Hour  Temperature(øC)  Humidity(%)  Wind speed (m/s)  \
# 0                   254     0             -5.2           37               2.2
# 1                   204     1             -5.5           38               0.8
# 2                   173     2             -6.0           39               1.0
# 3                   107     3             -6.2           40               0.9
# 4                    78     4             -6.0           36               2.3
# ...                 ...   ...              ...          ...               ...
# 8755               1003    19              4.2           34               2.6
# 8756                764    20              3.4           37               2.3
# 8757                694    21              2.6           39               0.3
# 8758                712    22              2.1           41               1.0
# 8759                584    23              1.9           43               1.3
#
# ...

# %% [markdown]
# # Model Building:

# %%
x=final_data.drop(columns=['Rented Bike Count'],axis=1)
x
# Out:
#       Hour  Temperature(øC)  Humidity(%)  Wind speed (m/s)  Visibility (10m)  \
# 0        0             -5.2           37               2.2              2000
# 1        1             -5.5           38               0.8              2000
# 2        2             -6.0           39               1.0              2000
# 3        3             -6.2           40               0.9              2000
# 4        4             -6.0           36               2.3              2000
# ...    ...              ...          ...               ...               ...
# 8755    19              4.2           34               2.6              1894
# 8756    20              3.4           37               2.3              2000
# 8757    21              2.6           39               0.3              1968
# 8758    22              2.1           41               1.0              1859
# 8759    23              1.9           43               1.3              1909
#
# ...

# %%
y=final_data["Rented Bike Count"]
y
# Out:
# 0        254
# 1        204
# 2        173
# 3        107
# 4         78
#         ...
# 8755    1003
# 8756     764
# 8757     694
# 8758     712
# 8759     584
# Name: Rented Bike Count, Length: 7641, dtype: int64

# %%
import pandas as pd
from sklearn.model_selection import train_test_split
x_train,x_test,y_train,y_test=train_test_split(x,y,test_size=0.2,random_state=42)
x_train.shape
# Out:
# (6112, 15)

# %%
x_train
# Out:
#       Hour  Temperature(øC)  Humidity(%)  Wind speed (m/s)  Visibility (10m)  \
# 5974    22             30.1           72               0.4              1806
# 428     20              3.3           65               3.2              1172
# 512      8             -0.4           69               0.5               904
# 5856     0             31.9           67               1.5              1550
# 3334    22             11.3           42               1.6              1189
# ...    ...              ...          ...               ...               ...
# 6036    12             31.1           63               3.0              1795
# 6237    21             27.1           43               1.6              2000
# 871      7             -6.6           65               1.0              1320
# 8722    10              3.9           28               0.6              1627
# 8386    10              8.6           57               0.6              1102
#
# ...

# %%
y_train
# Out:
# 5974    1371
# 428      165
# 512      544
# 5856     850
# 3334    1003
#         ...
# 6036     484
# 6237    2008
# 871      105
# 8722     595
# 8386     782
# Name: Rented Bike Count, Length: 6112, dtype: int64

# %%
x_train.shape
# Out:
# (6112, 15)

# %%
x_test.shape
# Out:
# (1529, 15)

# %%
y_train.shape
# Out:
# (6112,)

# %%
y_test.shape
# Out:
# (1529,)

# %%
print("x_train shape:",x_train.shape)
print("y_train shape:",y_train.shape)
print("x_test shape:",x_test.shape)
print("y_test shape:",y_test.shape)
# Out:
# x_train shape: (6112, 15)
# y_train shape: (6112,)
# x_test shape: (1529, 15)
# y_test shape: (1529,)

# %%
bfgrid_rmse={}

# %%
bfgrid_rsq={}

# %% [markdown]
# #K-Nearest Neighbors Regression (KNN)

# %%
import pandas as pd
from sklearn.preprocessing import StandardScaler
from sklearn.neighbors import KNeighborsRegressor

# %%
scaler=StandardScaler()
x_train=scaler.fit_transform(x_train)
x_test=scaler.transform(x_test)
from sklearn.metrics import mean_squared_error, r2_score
knn_regressor=KNeighborsRegressor(n_neighbors=5)
knn_regressor.fit(x_train,y_train)
# Out:
# KNeighborsRegressor()

# %%
y_pred=knn_regressor.predict(x_test)
y_pred
# Out:
# array([ 278.4,    0. ,  311. , ...,  293. ,  236.4, 2091.4])

# %%
mse=mean_squared_error(y_test,y_pred)
mse
# Out:
# 89642.20410725963

# %%
import numpy as np
rmse=np.sqrt(mse)
rmse
# Out:
# 299.40307965560345

# %%
from sklearn.metrics import mean_absolute_error, mean_squared_error, r2_score
rsq=r2_score(y_test,y_pred)
rsq
# Out:
# 0.7502394717619898

# %%
bfgrid_rmse["KNN"]=rmse
bfgrid_rmse
# Out:
# {'KNN': 299.40307965560345}

# %%
bfgrid_rsq["KNN"]=rsq
bfgrid_rsq
# Out:
# {'KNN': 0.7502394717619898}

# %% [markdown]
# #Principal Component Regression (PCR)

# %%
from sklearn.preprocessing import StandardScaler
from sklearn.decomposition import PCA
from sklearn.linear_model import LinearRegression
from sklearn.metrics import mean_squared_error, r2_score

# %%
scaler = StandardScaler()
X_scaled = scaler.fit_transform(x)

# %%
n_components=10
pca = PCA(n_components=n_components)
x_train_pca = pca.fit_transform(x_train)
x_test_pca = pca.transform(x_test)

# %%
regressor = LinearRegression()
regressor.fit(x_train_pca,y_train)
# Out:
# LinearRegression()

# %%
y_pred = regressor.predict(x_test_pca)

# %%
mse = mean_squared_error(y_test, y_pred)
r2 = r2_score(y_test, y_pred)
print(f"Mean Squared Error: {mse}")
print(f"R-squared: {r2}")
# Out:
# Mean Squared Error: 159818.42873536848
# R-squared: 0.5547149294170266

# %%
from sklearn.metrics import mean_squared_error
import numpy as np
mse=181797.17303985986
rmse = np.sqrt(mse)
rmse
# Out:
# 426.3767970233135

# %%
bfgrid_rmse["PCR"]=rmse
bfgrid_rmse
# Out:
# {'KNN': 299.40307965560345, 'PCR': 426.3767970233135}

# %%
bfgrid_rsq["PCR"]=r2
bfgrid_rsq
# Out:
# {'KNN': 0.7502394717619898, 'PCR': 0.5547149294170266}

# %% [markdown]
# #Partial Least Squares Regression (PLSR)

# %%
import numpy as np
import pandas as pd
from sklearn.cross_decomposition import PLSRegression
from sklearn.metrics import mean_squared_error,r2_score
from sklearn.model_selection import train_test_split
from sklearn.preprocessing import StandardScaler

# %%
scaler = StandardScaler()
x_scaled = scaler.fit_transform(x)

# %%
pls = PLSRegression(n_components=10)
pls.fit(x_train, y_train)
# Out:
# PLSRegression(n_components=10)

# %%
pls = PLSRegression(n_components=10)
pls.fit(x_train, y_train)
# Out:
# PLSRegression(n_components=10)

# %%
y_pred = pls.predict(x_test)

# %%
mse = mean_squared_error(y_test, y_pred)
r2 = r2_score(y_test, y_pred)
print(f"Mean Squared Error: {mse}")
print(f"R-squared: {r2}")
# Out:
# Mean Squared Error: 149572.68889802627
# R-squared: 0.5832615433635323

# %%
from sklearn.metrics import mean_squared_error
import numpy as np
mse=149849.4964251823
rmse = np.sqrt(mse)
rmse
# Out:
# 387.10398657877744

# %%
bfgrid_rmse["PLSR"]=rmse
bfgrid_rmse
# Out:
# {'KNN': 299.40307965560345,
#  'PCR': 426.3767970233135,
#  'PLSR': 387.10398657877744}

# %%
bfgrid_rsq["PLSR"]=r2
bfgrid_rsq
# Out:
# {'KNN': 0.7502394717619898,
#  'PCR': 0.5547149294170266,
#  'PLSR': 0.5832615433635323}

# %% [markdown]
# #Gradient Boosting

# %%
from sklearn.ensemble import GradientBoostingRegressor
from sklearn.metrics import mean_squared_error,r2_score
gbm=GradientBoostingRegressor(n_estimators=100,learning_rate=0.1,max_depth=3,random_state=42)
gbm.fit(x_train,y_train)
# Out:
# GradientBoostingRegressor(random_state=42)

# %%
gbm_y_pred=gbm.predict(x_test)
gbm_y_pred
# Out:
# array([ 337.78695202,  182.92119914,  143.77668796, ...,  273.05119441,
#          64.93862631, 1705.86696318])

# %%
mse=mean_squared_error(y_test,gbm_y_pred)
mse
# Out:
# 58755.65818274707

# %%
import numpy as np
rmse=np.sqrt(mse)
rmse
# Out:
# 242.39566452960142

# %%
r2=r2_score(y_test,gbm_y_pred)
r2
# Out:
# 0.8362953658844

# %%
bfgrid_rmse["Gradient Boosting"]=rmse
bfgrid_rmse
# Out:
# {'KNN': 299.40307965560345,
#  'PCR': 426.3767970233135,
#  'PLSR': 387.10398657877744,
#  'Gradient Boosting': 242.39566452960142}

# %%
bfgrid_rsq["Gradient Boosting"]=r2
bfgrid_rsq
# Out:
# {'KNN': 0.7502394717619898,
#  'PCR': 0.5547149294170266,
#  'PLSR': 0.5832615433635323,
#  'Gradient Boosting': 0.8362953658844}

# %% [markdown]
# #Decision Tree

# %%
import pandas as pd
from sklearn.tree import DecisionTreeRegressor
clf=DecisionTreeRegressor(random_state=42)
clf.fit(x_train,y_train)
clf_pred=clf.predict(x_test)
clf_pred
# Out:
# array([ 298.,    0.,   88., ...,  328.,  169., 2096.])

# %%
from sklearn.metrics import r2_score,mean_squared_error
mse=mean_squared_error(y_test,clf_pred)
mse
# Out:
# 98883.76586003925

# %%
import numpy as np
rmse=np.sqrt(mse)
rmse
# Out:
# 314.4578920301401

# %%
r_sq=r2_score(y_test,clf_pred)
r_sq
# Out:
# 0.7244906922880199

# %%
bfgrid_rmse["Decision Tree"]=rmse
bfgrid_rmse
# Out:
# {'KNN': 299.40307965560345,
#  'PCR': 426.3767970233135,
#  'PLSR': 387.10398657877744,
#  'Gradient Boosting': 242.39566452960142,
#  'Decision Tree': 314.4578920301401}

# %%
bfgrid_rsq["Decision Tree"]=r_sq
bfgrid_rsq
# Out:
# {'KNN': 0.7502394717619898,
#  'PCR': 0.5547149294170266,
#  'PLSR': 0.5832615433635323,
#  'Gradient Boosting': 0.8362953658844,
#  'Decision Tree': 0.7244906922880199}

# %%
feature_importance=clf.feature_importances_
importance_df=pd.DataFrame({"feature":x.columns,"Importance":feature_importance*100})
importance_df=importance_df.sort_values(by="Importance",ascending=False)
importance_df
# Out:
#                       feature  Importance
# 0                        Hour   31.227496
# 1             Temperature(øC)   31.008297
# 11            Functioning Day    9.618228
# 6     Solar Radiation (MJ/m2)    6.602123
# 2                 Humidity(%)    6.059296
# 9                     Seasons    4.765386
# 5   Dew point temperature(øC)    2.231892
# 3            Wind speed (m/s)    1.819119
# 4            Visibility (10m)    1.546027
# 13                      Month    1.544322
# 12                        Day    1.540895
# 7                Rainfall(mm)    1.355626
# 10                    Holiday    0.531396
# 8               Snowfall (cm)    0.099955
# 14                       Year    0.049943

# %% [markdown]
# #Random Forest Algorithm

# %%
import pandas as pd
from sklearn.ensemble import RandomForestRegressor
from sklearn.metrics import  r2_score,mean_squared_error

# %%
rf_model=RandomForestRegressor(n_estimators=100,random_state=42)
rf_model.fit(x_train,y_train)
# Out:
# RandomForestRegressor(random_state=42)

# %%
rf_y_pred=rf_model.predict(x_test)
rf_y_pred
# Out:
# array([ 292.6 ,    0.  ,  102.55, ...,  326.75,  113.11, 1981.61])

# %%
rf_mse=mean_squared_error(y_test,rf_y_pred)
rf_mse
# Out:
# 46464.46104571615

# %%
import numpy as np
rf_rmse=np.sqrt(rf_mse)
rf_rmse
# Out:
# 215.5561668004795

# %%
rf_r_sq=r2_score(y_test,rf_y_pred)
rf_r_sq
# Out:
# 0.8705410197055531

# %%
bfgrid_rmse["Random Forest"]=rf_rmse
bfgrid_rmse
# Out:
# {'KNN': 299.40307965560345,
#  'PCR': 426.3767970233135,
#  'PLSR': 387.10398657877744,
#  'Gradient Boosting': 242.39566452960142,
#  'Decision Tree': 314.4578920301401,
#  'Random Forest': 215.5561668004795}

# %%
bfgrid_rsq["Random Forest"]=rf_r_sq
bfgrid_rsq
# Out:
# {'KNN': 0.7502394717619898,
#  'PCR': 0.5547149294170266,
#  'PLSR': 0.5832615433635323,
#  'Gradient Boosting': 0.8362953658844,
#  'Decision Tree': 0.7244906922880199,
#  'Random Forest': 0.8705410197055531}

# %%
#Linear regression

# %%
from sklearn.linear_model import LinearRegression
model=LinearRegression()
model.fit(x_train,y_train)
from sklearn.metrics import mean_squared_error,r2_score
y_pred=model.predict(x_test)
y_pred
mse=mean_squared_error(y_test,y_pred)
mse
import numpy as np
rmse=np.sqrt(mse)
rmse
r2=r2_score(y_test,y_pred)
r2
# Out:
# 0.5826497956534302

# %%
bfgrid_rmse["Linear regression"]=rmse
bfgrid_rmse
# Out:
# {'KNN': 299.40307965560345,
#  'PCR': 426.3767970233135,
#  'PLSR': 387.10398657877744,
#  'Gradient Boosting': 242.39566452960142,
#  'Decision Tree': 314.4578920301401,
#  'Random Forest': 215.5561668004795,
#  'Linear regression': 387.0300412989587}

# %%
bfgrid_rsq["Linear regression"]=r2
bfgrid_rsq
# Out:
# {'KNN': 0.7502394717619898,
#  'PCR': 0.5547149294170266,
#  'PLSR': 0.5832615433635323,
#  'Gradient Boosting': 0.8362953658844,
#  'Decision Tree': 0.7244906922880199,
#  'Random Forest': 0.8705410197055531,
#  'Linear regression': 0.5826497956534302}

# %% [markdown]
# #Ridge regression

# %%
from sklearn.metrics import mean_absolute_error, mean_squared_error, r2_score
from sklearn.linear_model import Ridge
r_model=model.fit(x_train, y_train)
r_model
# Out:
# LinearRegression()

# %%
y_pred = r_model.predict(x_test)
y_pred
# Out:
# array([ 470.42415898,  471.24434546,  415.46279765, ...,  625.55241063,
#         138.78243303, 1158.20291932])

# %%
mse = mean_absolute_error(y_test, y_pred)
mse = mean_squared_error(y_test, y_pred)
rmse = mse ** 0.5
rmse
# Out:
# 387.0300412989587

# %%
r2 = r2_score(y_test, y_pred)
r2
# Out:
# 0.5826497956534302

# %%
bfgrid_rmse["Ridge regression"]=rmse
bfgrid_rmse
# Out:
# {'KNN': 299.40307965560345,
#  'PCR': 426.3767970233135,
#  'PLSR': 387.10398657877744,
#  'Gradient Boosting': 242.39566452960142,
#  'Decision Tree': 314.4578920301401,
#  'Random Forest': 215.5561668004795,
#  'Linear regression': 387.0300412989587,
#  'Ridge regression': 387.0300412989587}

# %%
bfgrid_rsq["Ridge regression"]=r2
bfgrid_rsq
# Out:
# {'KNN': 0.7502394717619898,
#  'PCR': 0.5547149294170266,
#  'PLSR': 0.5832615433635323,
#  'Gradient Boosting': 0.8362953658844,
#  'Decision Tree': 0.7244906922880199,
#  'Random Forest': 0.8705410197055531,
#  'Linear regression': 0.5826497956534302,
#  'Ridge regression': 0.5826497956534302}

# %% [markdown]
# #Elastic net regression

# %%
from sklearn.linear_model import ElasticNet
elastic_net=ElasticNet(alpha=1.0,l1_ratio=0.5,random_state=42)
elastic_net.fit(x_train,y_train)
y_pred=elastic_net.predict(x_test)
y_pred
mse=mean_squared_error(y_test,y_pred)
mse
rmse=np.sqrt(mse)
rmse
r2=r2_score(y_test,y_pred)
r2
# Out:
# 0.5336215042243599

# %%
bfgrid_rmse["Elastic net regression"]=rmse
bfgrid_rmse
# Out:
# {'KNN': 299.40307965560345,
#  'PCR': 426.3767970233135,
#  'PLSR': 387.10398657877744,
#  'Gradient Boosting': 242.39566452960142,
#  'Decision Tree': 314.4578920301401,
#  'Random Forest': 215.5561668004795,
#  'Linear regression': 387.0300412989587,
#  'Ridge regression': 387.0300412989587,
#  'Elastic net regression': 409.1321609371985}

# %%
bfgrid_rsq["Elastic net regression"]=r2
bfgrid_rsq
# Out:
# {'KNN': 0.7502394717619898,
#  'PCR': 0.5547149294170266,
#  'PLSR': 0.5832615433635323,
#  'Gradient Boosting': 0.8362953658844,
#  'Decision Tree': 0.7244906922880199,
#  'Random Forest': 0.8705410197055531,
#  'Linear regression': 0.5826497956534302,
#  'Ridge regression': 0.5826497956534302,
#  'Elastic net regression': 0.5336215042243599}

# %%
#Support vector Regressor

# %%
from sklearn.svm import SVR
svr=SVR(kernel='rbf',C=100,gamma=0.1,epsilon=0.1)
scaler=StandardScaler()
x_train_scaled=scaler.fit_transform(x_train)
x_test_scaled=scaler.transform(x_test)
svr.fit(x_train_scaled,y_train)
# Out:
# SVR(C=100, gamma=0.1)

# %%
y_pred=svr.predict(x_test_scaled)
y_pred
# Out:
# array([ 255.22727777,   -2.63608445,  229.69265785, ...,  405.83209076,
#         214.16961435, 1528.74698626])

# %%
mse=mean_squared_error(y_test,y_pred)
mse
# Out:
# 103702.9352117471

# %%
rmse=np.sqrt(mse)
rmse
# Out:
# 322.029401160433

# %%
from sklearn.metrics import mean_squared_error, r2_score
rsq=r2_score(y_test,y_pred)
rsq
# Out:
# 0.7110635538665817

# %%
bfgrid_rmse["SVR"]=rmse
bfgrid_rmse
# Out:
# {'KNN': 299.40307965560345,
#  'PCR': 426.3767970233135,
#  'PLSR': 387.10398657877744,
#  'Gradient Boosting': 242.39566452960142,
#  'Decision Tree': 314.4578920301401,
#  'Random Forest': 215.5561668004795,
#  'Linear regression': 387.0300412989587,
#  'Ridge regression': 387.0300412989587,
#  'Elastic net regression': 409.1321609371985,
#  'SVR': 322.029401160433}

# %%
bfgrid_rsq["SVR"]=rsq
bfgrid_rsq
# Out:
# {'KNN': 0.7502394717619898,
#  'PCR': 0.5547149294170266,
#  'PLSR': 0.5832615433635323,
#  'Gradient Boosting': 0.8362953658844,
#  'Decision Tree': 0.7244906922880199,
#  'Random Forest': 0.8705410197055531,
#  'Linear regression': 0.5826497956534302,
#  'Ridge regression': 0.5826497956534302,
#  'Elastic net regression': 0.5336215042243599,
#  'SVR': 0.7110635538665817}

# %%
import pandas as pd
import seaborn as sns
import matplotlib.pyplot as plt

# %%
model1={"model":['KNN','PCR','PLSR','Decision Tree','Random Forest','Linear regression','Ridge regression','Elastic Net','Support vector Regressor','Gradient Boosting']}

# %%
df1_rmse=pd.DataFrame(list(bfgrid_rmse.items()),columns=['model','bfgrid_rmse'])
df1_rmse
# Out:
#                     model  bfgrid_rmse
# 0                     KNN   299.403080
# 1                     PCR   426.376797
# 2                    PLSR   387.103987
# 3       Gradient Boosting   242.395665
# 4           Decision Tree   314.457892
# 5           Random Forest   215.556167
# 6       Linear regression   387.030041
# 7        Ridge regression   387.030041
# 8  Elastic net regression   409.132161
# 9                     SVR   322.029401

# %%
df1_rsq=pd.DataFrame(list(bfgrid_rsq.items()),columns=['model','bfgrid_rsq'])
df1_rsq
# Out:
#                     model  bfgrid_rsq
# 0                     KNN    0.750239
# 1                     PCR    0.554715
# 2                    PLSR    0.583262
# 3       Gradient Boosting    0.836295
# 4           Decision Tree    0.724491
# 5           Random Forest    0.870541
# 6       Linear regression    0.582650
# 7        Ridge regression    0.582650
# 8  Elastic net regression    0.533622
# 9                     SVR    0.711064

# %%
sns.barplot(x='model',y='bfgrid_rsq',data=df1_rsq,palette='viridis')
plt.xticks(rotation=90)
plt.show()

# %%
sns.barplot(x='model',y='bfgrid_rmse',data=df1_rmse,palette='viridis')
plt.xticks(rotation=90)
plt.show()

# %% [markdown]
# # Parameters tuning:

# %% [markdown]
# #Gride search CV

# %%
#Decision Tree

# %%
from sklearn.model_selection import GridSearchCV, train_test_split
from sklearn.metrics import mean_squared_error, r2_score
from sklearn.tree import DecisionTreeRegressor
model=DecisionTreeRegressor()
param_grid = {
    'max_depth': [None, 10, 20, 30],  # Fewer levels initially to keep search feasible
    'min_samples_split': [2, 5, 10],  # Commonly impactful on model generalization
    'min_samples_leaf': [1, 2, 5],  # Directly affects overfitting
}
grid_search = GridSearchCV(estimator=model, param_grid=param_grid, cv=5, scoring='neg_mean_squared_error', n_jobs=-1)
grid_search.fit(x_train, y_train)
best_model = grid_search.best_estimator_
y_pred = best_model.predict(x_test)
mse = mean_squared_error(y_test, y_pred)
print(f"Best parameters found: {grid_search.best_params_}")
print(f"Mean Squared Error on test set: {mse}")
rmse=np.sqrt(mse)
rmse
r2=r2_score(y_test,y_pred)
r2
print("RMSE:" ,rmse)
print("R_sq:" ,r2)
# Out:
# Best parameters found: {'max_depth': 10, 'min_samples_leaf': 1, 'min_samples_split': 10}
# Mean Squared Error on test set: 72491.35180960018
# RMSE: 269.242180591378
# R_sq: 0.7980250653030639

# %%
#Random Forest Regressor

# %%
from sklearn.model_selection import GridSearchCV, train_test_split
from sklearn.metrics import mean_squared_error, r2_score
from sklearn.ensemble import RandomForestRegressor
model=RandomForestRegressor()
param_grid = {
    "n_estimators":[100,200,300],
    'max_depth': [None, 10, 20, 30],  
    'min_samples_split': [2, 5, 10],  
    'min_samples_leaf': [1, 2, 5], 
    "max_features":["auto","sqrt","log2"],
    "bootstrap":[True,False]
}
grid_search = GridSearchCV(estimator=model, param_grid=param_grid, cv=5, scoring='neg_mean_squared_error', n_jobs=-1)
grid_search.fit(x_train, y_train)
best_model = grid_search.best_estimator_
y_pred = best_model.predict(x_test)
mse = mean_squared_error(y_test, y_pred)
print(f"Best parameters found: {grid_search.best_params_}")
print(f"Mean Squared Error on test set: {mse}")
rmse=np.sqrt(mse)
rmse
r2=r2_score(y_test,y_pred)
r2
print("RMSE:" ,rmse)
print("R_sq:" ,r2)

# %% [markdown]
# Best parameters found: {'bootstrap': False, 'max_depth': None, 'max_features': 'sqrt', 'min_samples_leaf': 1, 'min_samples_split': 2, 'n_estimators': 300}
# Mean Squared Error on test set: 46836.87222874646
# RMSE: 216.4182807175643
# R_sq: 0.8695034100804696

# %%
#LinearRegression

# %%
from sklearn.model_selection import GridSearchCV, train_test_split
from sklearn.metrics import mean_squared_error, r2_score
model=LinearRegression()
param_grid={'fit_intercept':[True,False]}
grid_search = GridSearchCV(estimator=model, param_grid=param_grid, cv=5, scoring='neg_mean_squared_error')
grid_search.fit(x_train, y_train)
best_model = grid_search.best_estimator_
y_pred = best_model.predict(x_test)
mse = mean_squared_error(y_test, y_pred)
print(f"Best parameters found: {grid_search.best_params_}")
print(f"Mean Squared Error on test set: {mse}")
rmse=np.sqrt(mse)
rmse
r2=r2_score(y_test,y_pred)
r2
print("RMSE:" ,rmse)
print("R_sq:" ,r2)
# Out:
# Best parameters found: {'fit_intercept': True}
# Mean Squared Error on test set: 149852.07298456875
# RMSE: 387.1073145583389
# R_sq: 0.5824831252319048

# %%
#Elastic Net

# %%
from sklearn.model_selection import GridSearchCV, train_test_split
from sklearn.metrics import mean_squared_error, r2_score
model=ElasticNet()
param_grid={'alpha':[0.1,1.0,10.0],'l1_ratio':[0.1,0.5,0.9]}
grid_search = GridSearchCV(estimator=model, param_grid=param_grid, cv=5, scoring='neg_mean_squared_error')
grid_search.fit(x_train, y_train)
best_model = grid_search.best_estimator_
y_pred = best_model.predict(x_test)
mse = mean_squared_error(y_test, y_pred)
print(f"Best parameters found: {grid_search.best_params_}")
print(f"Mean Squared Error on test set: {mse}")
rmse=np.sqrt(mse)
rmse
r2=r2_score(y_test,y_pred)
r2
print("RMSE:" ,rmse)
print("R_sq:" ,r2)
# Out:
# Best parameters found: {'alpha': 0.1, 'l1_ratio': 0.9}
# Mean Squared Error on test set: 149659.21183072845
# RMSE: 386.85812881562725
# R_sq: 0.5830204737290714

# %%
#Gradient Boosting Regressor

# %%
from sklearn.model_selection import GridSearchCV, train_test_split
from sklearn.metrics import mean_squared_error, r2_score
gbr_model=GradientBoostingRegressor()
param_grid={'n_estimators':[100,200,300],'learning_rate':[0.01,0.1,0.2],'max_depth':[3,4,5],'subsample':[0.8,0.9,1.0]}
grid_search = GridSearchCV(estimator=gbr_model, param_grid=param_grid, cv=5, scoring='neg_mean_squared_error',n_jobs=-1,verbose=2)
grid_search.fit(x_train, y_train)
best_model = grid_search.best_estimator_
y_pred_gbr= best_model.predict(x_test)
mse = mean_squared_error(y_test, y_pred_gbr)
print(f"Best parameters found: {grid_search.best_params_}")
print(f"Mean Squared Error on test set: {mse}")
rmse=np.sqrt(mse)
rmse
r2=r2_score(y_test,y_pred_gbr)
r2
print("RMSE:" ,rmse)
print("R_sq:" ,r2)
# Out:
# Fitting 5 folds for each of 81 candidates, totalling 405 fits
# Best parameters found: {'learning_rate': 0.1, 'max_depth': 5, 'n_estimators': 200, 'subsample': 0.9}
# Mean Squared Error on test set: 49696.029980528074
# RMSE: 222.9260639327041
# R_sq: 0.8615372432786546

# %%
#KNN

# %%
from sklearn.model_selection import GridSearchCV, train_test_split
from sklearn.metrics import mean_squared_error, r2_score
knn_model=KNeighborsRegressor()
param_grid={'n_neighbors':[3,5,7,9,11],'weights':['uniform','distance'],'metric':['euclidean','manhattan']}
grid_search = GridSearchCV(estimator=knn_model, param_grid=param_grid, cv=5, scoring='neg_mean_squared_error',n_jobs=-1,verbose=2)
grid_search.fit(x_train, y_train)
best_model = grid_search.best_estimator_
y_pred_knn= best_model.predict(x_test)
mse = mean_squared_error(y_test, y_pred_knn)
print(f"Best parameters found: {grid_search.best_params_}")
print(f"Mean Squared Error on test set: {mse}")
rmse=np.sqrt(mse)
rmse
r2=r2_score(y_test,y_pred_knn)
r2
print("RMSE:" ,rmse)
print("R_sq:" ,r2)
# Out:
# Fitting 5 folds for each of 20 candidates, totalling 100 fits
# Best parameters found: {'metric': 'manhattan', 'n_neighbors': 5, 'weights': 'distance'}
# Mean Squared Error on test set: 71471.95149422043
# RMSE: 267.34238626566577
# R_sq: 0.8008653118564686

# %%
#Ridge Regression

# %%
from sklearn.model_selection import GridSearchCV, train_test_split
from sklearn.metrics import mean_squared_error, r2_score
model=Ridge()
param_grid={'alpha':[0.1,1.0,10.0,100.0]}
grid_search = GridSearchCV(estimator=model, param_grid=param_grid, cv=5, scoring='neg_mean_squared_error')
grid_search.fit(x_train, y_train)
best_model = grid_search.best_estimator_
y_pred_r = best_model.predict(x_test)
mse = mean_squared_error(y_test, y_pred_r)
print(f"Best parameters found: {grid_search.best_params_}")
print(f"Mean Squared Error on test set: {mse}")
rmse=np.sqrt(mse)
rmse
r2=r2_score(y_test,y_pred_r)
r2
print("RMSE:" ,rmse)
print("R_sq:" ,r2)
# Out:
# Best parameters found: {'alpha': 1.0}
# Mean Squared Error on test set: 149834.355256761
# RMSE: 387.0844291065723
# R_sq: 0.5825324902503191

# %%
#PLSRegression

# %%
import numpy as np
import pandas as pd
from sklearn.model_selection import GridSearchCV, train_test_split
from sklearn.cross_decomposition import PLSRegression
from sklearn.metrics import mean_squared_error
pls = PLSRegression()
param_grid = {'n_components': [2, 3, 4, 5, 6, 7, 8, 9, 10]}
grid_search = GridSearchCV(estimator=pls, param_grid=param_grid, cv=5, scoring='neg_mean_squared_error')
grid_search.fit(x_train, y_train)
print(f"Best parameters: {grid_search.best_params_}")
print(f"Best cross-validation score: {grid_search.best_score_}")
best_model = grid_search.best_estimator_
y_pred = best_model.predict(x_test)
mse = mean_squared_error(y_test, y_pred)
print(f"Test MSE: {mse}")
rmse=np.sqrt(mse)
rmse
r2=r2_score(y_test,y_pred)
r2
# Out:
# Best parameters: {'n_components': 9}
# Best cross-validation score: -150410.2100474201
# Test MSE: 149855.59411935412
# 0.5824733146689813

# %%
#PCR

# %%
from sklearn.model_selection import GridSearchCV, train_test_split
from sklearn.pipeline import Pipeline
pca=PCA()
regressor=LinearRegression()
Pipeline = Pipeline(steps=[('pca', pca), ('regressor', regressor)])
param_grid = {
    'pca__n_components': [5, 10, 15, 20, 25, 30], 
    'regressor__fit_intercept': [True, False],  
}
grid_search = GridSearchCV(estimator=Pipeline, param_grid=param_grid, cv=5, scoring='neg_mean_squared_error', n_jobs=-1, verbose=2)
grid_search.fit(x_train, y_train)
print(f"Best parameters: {grid_search.best_params_}")
best_model = grid_search.best_estimator_
y_pred_pcr = best_model.predict(x_test)
mse = mean_squared_error(y_test, y_pred_pcr)
mse
rmse=np.sqrt(mse)
rmse
r2=r2_score(y_test,y_pred_pcr)
r2
print("RMSE:" ,rmse)
print("R_sq:" ,r2)
print("RMSE:" ,rmse)
print("R_sq:" ,r2)

# %% [markdown]
# Fitting 5 folds for each of 12 candidates, totalling 60 fits
# Best parameters: {'pca__n_components': 15, 'regressor__fit_intercept': True}
# RMSE: 387.03004129895857
# R_sq: 0.5826497956534304
# RMSE: 387.03004129895857
# R_sq: 0.5826497956534304

# %%
#SVR

# %%
from sklearn.model_selection import GridSearchCV, train_test_split
from sklearn.metrics import mean_squared_error, r2_score
svr_model=SVR()
param_grid={'C':[0.1,1,10,100],'epsilon':[0.01,0.1,0.2],'kernel':['linear','poly','rbf'],'degree':[2,3,4],'gamma':['scale','auto']}
grid_search = GridSearchCV(estimator=svr_model, param_grid=param_grid, cv=5, scoring='neg_mean_squared_error',n_jobs=-1,verbose=2)
grid_search.fit(x_train, y_train)
best_model = grid_search.best_estimator_
y_pred_svr= best_model.predict(x_test)
mse = mean_squared_error(y_test, y_pred_svr)
print(f"Best parameters found: {grid_search.best_params_}")
print(f"Mean Squared Error on test set: {mse}")
rmse=np.sqrt(mse)
rmse
r2=r2_score(y_test,y_pred_svr)
r2
print("RMSE:" ,rmse)
print("R_sq:" ,r2)
# Out:
# Fitting 5 folds for each of 216 candidates, totalling 1080 fits

# %% [markdown]
# Best parameters found: {'C': 100, 'degree': 2, 'epsilon': 0.2, 'gamma': 'auto', 'kernel': 'rbf'}
# Mean Squared Error on test set: 107552.20084331864
# RMSE: 327.9515220933098
# R_sq: 0.7003387549055992

# %% [markdown]
# # After Grid Search Models

# %%
afgrid_rmse={}

# %%
afgrid_rsq={}

# %% [markdown]
# #K-Nearest Neighbors Regression (KNN)

# %%
import pandas as pd
from sklearn.preprocessing import StandardScaler
from sklearn.neighbors import KNeighborsRegressor

# %%
scaler=StandardScaler()
x_train=scaler.fit_transform(x_train)
x_test=scaler.transform(x_test)
from sklearn.metrics import mean_squared_error, r2_score
knn_regressor=KNeighborsRegressor(metric='manhattan', n_neighbors=5,weights='distance')
knn_regressor.fit(x_train,y_train)
# Out:
# KNeighborsRegressor(metric='manhattan', weights='distance')

# %%
y_pred=knn_regressor.predict(x_test)
y_pred
# Out:
# array([ 287.7289071 ,    0.        ,  377.61836318, ...,  308.95425369,
#         261.20533212, 2086.26089631])

# %%
mse=mean_squared_error(y_test,y_pred)
mse
# Out:
# 76510.79917323258

# %%
import numpy as np
rmse=np.sqrt(mse)
rmse
# Out:
# 276.60585527647925

# %%
from sklearn.metrics import mean_absolute_error, mean_squared_error, r2_score
rsq=r2_score(y_test,y_pred)
rsq
# Out:
# 0.786826107102923

# %%
afgrid_rmse["KNN"]=rmse
afgrid_rmse
# Out:
# {'KNN': 276.60585527647925}

# %%
afgrid_rsq["KNN"]=rsq
afgrid_rsq
# Out:
# {'KNN': 0.786826107102923}

# %% [markdown]
# #Principal Component Regression (PCR)

# %%
from sklearn.preprocessing import StandardScaler
from sklearn.decomposition import PCA
from sklearn.linear_model import LinearRegression
from sklearn.metrics import mean_squared_error, r2_score

# %%
scaler = StandardScaler()
X_scaled = scaler.fit_transform(x)

# %%
pca = PCA(n_components=15)
x_train_pca = pca.fit_transform(x_train)
x_test_pca = pca.transform(x_test)

# %%
regressor = LinearRegression()
regressor.fit(x_train_pca,y_train)
# Out:
# LinearRegression()

# %%
y_pred = regressor.predict(x_test_pca)

# %%
mse = mean_squared_error(y_test, y_pred)
r2 = r2_score(y_test, y_pred)
print(f"Mean Squared Error: {mse}")
print(f"R-squared: {r2}")
# Out:
# Mean Squared Error: 149792.2528678736
# R-squared: 0.5826497956534302

# %%
from sklearn.metrics import mean_squared_error
import numpy as np
mse=181797.17303985986
rmse = np.sqrt(mse)
rmse
# Out:
# 426.3767970233135

# %%
afgrid_rmse["PCR"]=rmse
afgrid_rmse
# Out:
# {'KNN': 276.60585527647925, 'PCR': 426.3767970233135}

# %%
afgrid_rsq["PCR"]=r2
afgrid_rsq
# Out:
# {'KNN': 0.786826107102923, 'PCR': 0.5826497956534302}

# %% [markdown]
# #Partial Least Squares Regression (PLSR)

# %%
import numpy as np
import pandas as pd
from sklearn.cross_decomposition import PLSRegression
from sklearn.metrics import mean_squared_error,r2_score
from sklearn.model_selection import train_test_split
from sklearn.preprocessing import StandardScaler

# %%
scaler = StandardScaler()
x_scaled = scaler.fit_transform(x)

# %%
pls = PLSRegression(n_components=9)
pls.fit(x_train, y_train)
# Out:
# PLSRegression(n_components=9)

# %%
y_pred = pls.predict(x_test)

# %%
mse = mean_squared_error(y_test, y_pred)
r2 = r2_score(y_test, y_pred)
print(f"Mean Squared Error: {mse}")
print(f"R-squared: {r2}")
# Out:
# Mean Squared Error: 149344.62237893595
# R-squared: 0.5838969808212419

# %%
from sklearn.metrics import mean_squared_error
import numpy as np
mse=149849.4964251823
rmse = np.sqrt(mse)
rmse
# Out:
# 387.10398657877744

# %%
afgrid_rmse["PLSR"]=rmse
afgrid_rmse
# Out:
# {'KNN': 276.60585527647925,
#  'PCR': 426.3767970233135,
#  'PLSR': 387.10398657877744}

# %%
afgrid_rsq["PLSR"]=r2
afgrid_rsq
# Out:
# {'KNN': 0.786826107102923,
#  'PCR': 0.5826497956534302,
#  'PLSR': 0.5838969808212419}

# %% [markdown]
# #Gradient Boosting

# %%
from sklearn.ensemble import GradientBoostingRegressor
from sklearn.metrics import mean_squared_error,r2_score
gbm=GradientBoostingRegressor(learning_rate=0.1,max_depth=5,n_estimators=300,subsample=0.9)
gbm.fit(x_train,y_train)
# Out:
# GradientBoostingRegressor(max_depth=5, n_estimators=300, subsample=0.9)

# %%
gbm_y_pred=gbm.predict(x_test)
gbm_y_pred
# Out:
# array([ 299.61636726,  -71.77451405,  105.43482246, ...,  284.14218637,
#         118.65704105, 1871.10062806])

# %%
mse=mean_squared_error(y_test,gbm_y_pred)
mse
# Out:
# 43747.10731910488

# %%
import numpy as np
rmse=np.sqrt(mse)
rmse
# Out:
# 209.15809168928865

# %%
r2=r2_score(y_test,gbm_y_pred)
r2
# Out:
# 0.8781120930512718

# %%
afgrid_rmse["Gradient Boosting"]=rmse
afgrid_rmse
# Out:
# {'KNN': 276.60585527647925,
#  'PCR': 426.3767970233135,
#  'PLSR': 387.10398657877744,
#  'Gradient Boosting': 209.15809168928865}

# %%
afgrid_rsq["Gradient Boosting"]=r2
afgrid_rsq
# Out:
# {'KNN': 0.786826107102923,
#  'PCR': 0.5826497956534302,
#  'PLSR': 0.5838969808212419,
#  'Gradient Boosting': 0.8781120930512718}

# %% [markdown]
# #Decision Tree

# %%
import pandas as pd
from sklearn.tree import DecisionTreeRegressor
clf=DecisionTreeRegressor(max_depth=10,min_samples_leaf=1,min_samples_split=10)
clf.fit(x_train,y_train)
clf_pred=clf.predict(x_test)
clf_pred
# Out:
# array([ 316.60869565,    0.        ,   90.2173913 , ...,  291.51428571,
#         118.66666667, 1948.06296296])

# %%
from sklearn.metrics import r2_score,mean_squared_error
mse=mean_squared_error(y_test,clf_pred)
mse
# Out:
# 70376.11064307182

# %%
import numpy as np
rmse=np.sqrt(mse)
rmse
# Out:
# 265.2849612078902

# %%
r_sq=r2_score(y_test,clf_pred)
r_sq
# Out:
# 0.8039185365353283

# %%
afgrid_rmse["Decision Tree"]=rmse
afgrid_rmse
# Out:
# {'KNN': 276.60585527647925,
#  'PCR': 426.3767970233135,
#  'PLSR': 387.10398657877744,
#  'Gradient Boosting': 209.15809168928865,
#  'Decision Tree': 265.2849612078902}

# %%
afgrid_rsq["Decision Tree"]=r_sq
afgrid_rsq
# Out:
# {'KNN': 0.786826107102923,
#  'PCR': 0.5826497956534302,
#  'PLSR': 0.5838969808212419,
#  'Gradient Boosting': 0.8781120930512718,
#  'Decision Tree': 0.8039185365353283}

# %% [markdown]
# #Random Forest Algorithm

# %%
import pandas as pd
from sklearn.ensemble import RandomForestRegressor
from sklearn.metrics import  r2_score,mean_squared_error

# %%
rf_model=RandomForestRegressor(bootstrap=False,max_depth=None,max_features='sqrt',min_samples_leaf=1,min_samples_split=2,n_estimators=300)
rf_model.fit(x_train,y_train)
# Out:
# RandomForestRegressor(bootstrap=False, max_features='sqrt', n_estimators=300)

# %%
rf_y_pred=rf_model.predict(x_test)
rf_y_pred
# Out:
# array([ 296.86      ,   35.34666667,  147.46333333, ...,  321.39      ,
#         173.48666667, 1897.86333333])

# %%
rf_mse=mean_squared_error(y_test,rf_y_pred)
rf_mse
# Out:
# 45428.01233838404

# %%
import numpy as np
rf_rmse=np.sqrt(rf_mse)
rf_rmse
# Out:
# 213.1384815991332

# %%
rf_r_sq=r2_score(y_test,rf_y_pred)
rf_r_sq
# Out:
# 0.8734287663781486

# %%
afgrid_rmse["Random Forest"]=rf_rmse
afgrid_rmse
# Out:
# {'KNN': 276.60585527647925,
#  'PCR': 426.3767970233135,
#  'PLSR': 387.10398657877744,
#  'Gradient Boosting': 209.15809168928865,
#  'Decision Tree': 265.2849612078902,
#  'Random Forest': 213.1384815991332}

# %%
afgrid_rsq["Random Forest"]=rf_r_sq
afgrid_rsq
# Out:
# {'KNN': 0.786826107102923,
#  'PCR': 0.5826497956534302,
#  'PLSR': 0.5838969808212419,
#  'Gradient Boosting': 0.8781120930512718,
#  'Decision Tree': 0.8039185365353283,
#  'Random Forest': 0.8734287663781486}

# %%
#Linear regression

# %%
from sklearn.linear_model import LinearRegression
model=LinearRegression(fit_intercept=True)
model.fit(x_train,y_train)
from sklearn.metrics import mean_squared_error,r2_score
y_pred=model.predict(x_test)
y_pred
mse=mean_squared_error(y_test,y_pred)
mse
import numpy as np
rmse=np.sqrt(mse)
rmse
r2=r2_score(y_test,y_pred)
r2
# Out:
# 0.5826497956534302

# %%
afgrid_rmse["Linear regression"]=rmse
afgrid_rmse
# Out:
# {'KNN': 276.60585527647925,
#  'PCR': 426.3767970233135,
#  'PLSR': 387.10398657877744,
#  'Gradient Boosting': 209.15809168928865,
#  'Decision Tree': 265.2849612078902,
#  'Random Forest': 213.1384815991332,
#  'Linear regression': 387.0300412989587}

# %%
afgrid_rsq["Linear regression"]=r2
afgrid_rsq
# Out:
# {'KNN': 0.786826107102923,
#  'PCR': 0.5826497956534302,
#  'PLSR': 0.5838969808212419,
#  'Gradient Boosting': 0.8781120930512718,
#  'Decision Tree': 0.8039185365353283,
#  'Random Forest': 0.8734287663781486,
#  'Linear regression': 0.5826497956534302}

# %% [markdown]
# #Ridge regression

# %%
from sklearn.metrics import mean_absolute_error, mean_squared_error, r2_score
from sklearn.linear_model import Ridge
r_model=Ridge(alpha=1.0)
r_model=model.fit(x_train, y_train)
r_model
# Out:
# LinearRegression()

# %%
y_pred = r_model.predict(x_test)
y_pred
# Out:
# array([ 470.42415898,  471.24434546,  415.46279765, ...,  625.55241063,
#         138.78243303, 1158.20291932])

# %%
mse = mean_absolute_error(y_test, y_pred)
mse = mean_squared_error(y_test, y_pred)
rmse = mse ** 0.5
rmse
# Out:
# 387.0300412989587

# %%
r2 = r2_score(y_test, y_pred)
r2
# Out:
# 0.5826497956534302

# %%
afgrid_rmse["Ridge regression"]=rmse
afgrid_rmse
# Out:
# {'KNN': 276.60585527647925,
#  'PCR': 426.3767970233135,
#  'PLSR': 387.10398657877744,
#  'Gradient Boosting': 209.15809168928865,
#  'Decision Tree': 265.2849612078902,
#  'Random Forest': 213.1384815991332,
#  'Linear regression': 387.0300412989587,
#  'Ridge regression': 387.0300412989587}

# %%
afgrid_rsq["Ridge regression"]=r2
afgrid_rsq
# Out:
# {'KNN': 0.786826107102923,
#  'PCR': 0.5826497956534302,
#  'PLSR': 0.5838969808212419,
#  'Gradient Boosting': 0.8781120930512718,
#  'Decision Tree': 0.8039185365353283,
#  'Random Forest': 0.8734287663781486,
#  'Linear regression': 0.5826497956534302,
#  'Ridge regression': 0.5826497956534302}

# %% [markdown]
# #Support vector Regressor

# %%
from sklearn.svm import SVR
svr=SVR(C=100,degree=2,epsilon=0.2,gamma='auto',kernel='rbf')
scaler=StandardScaler()
x_train_scaled=scaler.fit_transform(x_train)
x_test_scaled=scaler.transform(x_test)
svr.fit(x_train_scaled,y_train)
# Out:
# SVR(C=100, degree=2, epsilon=0.2, gamma='auto')

# %%
y_pred=svr.predict(x_test_scaled)
y_pred
# Out:
# array([2.58191563e+02, 6.47915781e-01, 2.51939568e+02, ...,
#        4.05644856e+02, 2.11631908e+02, 1.45293403e+03])

# %%
mse=mean_squared_error(y_test,y_pred)
mse
# Out:
# 107552.20084331869

# %%
rmse=np.sqrt(mse)
rmse
# Out:
# 327.95152209330985

# %%
from sklearn.metrics import mean_squared_error, r2_score
rsq=r2_score(y_test,y_pred)
rsq
# Out:
# 0.700338754905599

# %%
afgrid_rmse["SVR"]=rmse
afgrid_rmse
# Out:
# {'KNN': 276.60585527647925,
#  'PCR': 426.3767970233135,
#  'PLSR': 387.10398657877744,
#  'Gradient Boosting': 209.15809168928865,
#  'Decision Tree': 265.2849612078902,
#  'Random Forest': 213.1384815991332,
#  'Linear regression': 387.0300412989587,
#  'Ridge regression': 387.0300412989587,
#  'SVR': 327.95152209330985}

# %%
afgrid_rsq["SVR"]=rsq
afgrid_rsq
# Out:
# {'KNN': 0.786826107102923,
#  'PCR': 0.5826497956534302,
#  'PLSR': 0.5838969808212419,
#  'Gradient Boosting': 0.8781120930512718,
#  'Decision Tree': 0.8039185365353283,
#  'Random Forest': 0.8734287663781486,
#  'Linear regression': 0.5826497956534302,
#  'Ridge regression': 0.5826497956534302,
#  'SVR': 0.700338754905599}

# %%
#Elastic Net

# %%
from sklearn.linear_model import ElasticNet
elastic_net=ElasticNet(alpha=0.1,l1_ratio=0.9)
elastic_net.fit(x_train,y_train)
y_pred=elastic_net.predict(x_test)
y_pred
mse=mean_squared_error(y_test,y_pred)
mse
rmse=np.sqrt(mse)
rmse
r2=r2_score(y_test,y_pred)
r2
# Out:
# 0.5833062946037728

# %%
afgrid_rmse["Elastic Net"]=rmse
afgrid_rmse
# Out:
# {'KNN': 276.60585527647925,
#  'PCR': 426.3767970233135,
#  'PLSR': 387.10398657877744,
#  'Gradient Boosting': 209.15809168928865,
#  'Decision Tree': 265.2849612078902,
#  'Random Forest': 213.1384815991332,
#  'Linear regression': 387.0300412989587,
#  'Ridge regression': 387.0300412989587,
#  'SVR': 327.95152209330985,
#  'Elastic Net': 386.7255190873807}

# %%
afgrid_rsq["Elastic Net"]=r2
afgrid_rsq
# Out:
# {'KNN': 0.786826107102923,
#  'PCR': 0.5826497956534302,
#  'PLSR': 0.5838969808212419,
#  'Gradient Boosting': 0.8781120930512718,
#  'Decision Tree': 0.8039185365353283,
#  'Random Forest': 0.8734287663781486,
#  'Linear regression': 0.5826497956534302,
#  'Ridge regression': 0.5826497956534302,
#  'SVR': 0.700338754905599,
#  'Elastic Net': 0.5833062946037728}

# %%
import pandas as pd
import seaborn as sns
import matplotlib.pyplot as plt

# %%
model={"model":['KNN','PCR','PLSR','Decision Tree','Random Forest','Linear regression','Ridge regression','Elastic Net','SVR','Gradient Boosting']}

# %%
df2_rmse=pd.DataFrame(list(afgrid_rmse.items()),columns=['model','afgrid_rmse'])
df2_rmse
# Out:
#                model  afgrid_rmse
# 0                KNN   276.605855
# 1                PCR   426.376797
# 2               PLSR   387.103987
# 3  Gradient Boosting   209.158092
# 4      Decision Tree   265.284961
# 5      Random Forest   213.138482
# 6  Linear regression   387.030041
# 7   Ridge regression   387.030041
# 8                SVR   327.951522
# 9        Elastic Net   386.725519

# %%
sns.barplot(x='model',y='afgrid_rmse',data=df2_rmse,palette='viridis')
plt.xticks(rotation=90)
plt.show()

# %%
sns.barplot(x='model',y='afgrid_rsq',data=df2_rsq,palette='viridis')
plt.xticks(rotation=90)
plt.show()

# %%
df2_rsq=pd.DataFrame(list(afgrid_rsq.items()),columns=['model','afgrid_rsq'])
df2_rsq
# Out:
#                model  afgrid_rsq
# 0                KNN    0.786826
# 1                PCR    0.582650
# 2               PLSR    0.583897
# 3  Gradient Boosting    0.878112
# 4      Decision Tree    0.803919
# 5      Random Forest    0.873429
# 6  Linear regression    0.582650
# 7   Ridge regression    0.582650
# 8                SVR    0.700339
# 9        Elastic Net    0.583306

# %% [markdown]
# # After variable selection

# %%
x=final_data[['Hour','Temperature(øC)','Functioning Day','Solar Radiation (MJ/m2)','Humidity(%)','Seasons']]
x
# Out:
#       Hour  Temperature(øC)  Functioning Day  Solar Radiation (MJ/m2)  \
# 0        0             -5.2                1                      0.0
# 1        1             -5.5                1                      0.0
# 2        2             -6.0                1                      0.0
# 3        3             -6.2                1                      0.0
# 4        4             -6.0                1                      0.0
# ...    ...              ...              ...                      ...
# 8755    19              4.2                1                      0.0
# 8756    20              3.4                1                      0.0
# 8757    21              2.6                1                      0.0
# 8758    22              2.1                1                      0.0
# 8759    23              1.9                1                      0.0
#
#       Humidity(%)  Seasons
# 0              37        3
# 1              38        3
# 2              39        3
# ...

# %%
y=final_data["Rented Bike Count"]
y
# Out:
# 0        254
# 1        204
# 2        173
# 3        107
# 4         78
#         ...
# 8755    1003
# 8756     764
# 8757     694
# 8758     712
# 8759     584
# Name: Rented Bike Count, Length: 7641, dtype: int64

# %%
import pandas as pd
from sklearn.model_selection import train_test_split
x_train,x_test,y_train,y_test=train_test_split(x,y,test_size=0.2,random_state=42)
x_train.shape
# Out:
# (6112, 6)

# %%
x_train
# Out:
#       Hour  Temperature(øC)  Functioning Day  Solar Radiation (MJ/m2)  \
# 5974    22             30.1                1                     0.00
# 428     20              3.3                1                     0.00
# 512      8             -0.4                1                     0.00
# 5856     0             31.9                1                     0.00
# 3334    22             11.3                1                     0.00
# ...    ...              ...              ...                      ...
# 6036    12             31.1                1                     1.14
# 6237    21             27.1                1                     0.00
# 871      7             -6.6                1                     0.00
# 8722    10              3.9                1                     0.49
# 8386    10              8.6                1                     0.77
#
#       Humidity(%)  Seasons
# 5974           72        2
# 428            65        3
# 512            69        3
# ...

# %%
y_train
# Out:
# 5974    1371
# 428      165
# 512      544
# 5856     850
# 3334    1003
#         ...
# 6036     484
# 6237    2008
# 871      105
# 8722     595
# 8386     782
# Name: Rented Bike Count, Length: 6112, dtype: int64

# %%
x_train.shape
# Out:
# (6112, 6)

# %%
x_test.shape
# Out:
# (1529, 6)

# %%
y_train.shape
# Out:
# (6112,)

# %%
y_test.shape
# Out:
# (1529,)

# %%
print("x_train shape:",x_train.shape)
print("y_train shape:",y_train.shape)
print("x_test shape:",x_test.shape)
print("y_test shape:",y_test.shape)
# Out:
# x_train shape: (6112, 6)
# y_train shape: (6112,)
# x_test shape: (1529, 6)
# y_test shape: (1529,)

# %%
variable_selection_rmse={}

# %%
variable_selection_rsq={}

# %% [markdown]
# #K-Nearest Neighbors Regression (KNN)

# %%
import pandas as pd
from sklearn.preprocessing import StandardScaler
from sklearn.neighbors import KNeighborsRegressor

# %%
scaler=StandardScaler()
x_train=scaler.fit_transform(x_train)
x_test=scaler.transform(x_test)
from sklearn.metrics import mean_squared_error, r2_score
knn_regressor=KNeighborsRegressor(n_neighbors=5)
knn_regressor.fit(x_train,y_train)
# Out:
# KNeighborsRegressor()

# %%
y_pred=knn_regressor.predict(x_test)
y_pred
# Out:
# array([ 308. ,    0. ,  131. , ...,  323.8,  162. , 1986.4])

# %%
mse=mean_squared_error(y_test,y_pred)
mse
# Out:
# 73167.57213865271

# %%
import numpy as np
rmse=np.sqrt(mse)
rmse
# Out:
# 270.4950501185793

# %%
from sklearn.metrics import mean_absolute_error, mean_squared_error, r2_score
rsq=r2_score(y_test,y_pred)
rsq
# Out:
# 0.7961409846038952

# %%
variable_selection_rmse["KNN"]=rmse
variable_selection_rmse
# Out:
# {'KNN': 270.4950501185793}

# %%
variable_selection_rsq["KNN"]=rsq
variable_selection_rsq
# Out:
# {'KNN': 0.7961409846038952}

# %% [markdown]
# #Principal Component Regression (PCR)

# %%
from sklearn.preprocessing import StandardScaler
from sklearn.decomposition import PCA
from sklearn.linear_model import LinearRegression
from sklearn.metrics import mean_squared_error, r2_score

# %%
scaler = StandardScaler()
X_scaled = scaler.fit_transform(x)

# %%
n_components=5
pca = PCA(n_components=n_components)
x_train_pca = pca.fit_transform(x_train)
x_test_pca = pca.transform(x_test)

# %%
regressor = LinearRegression()
regressor.fit(x_train_pca,y_train)
# Out:
# LinearRegression()

# %%
y_pred = regressor.predict(x_test_pca)

# %%
mse = mean_squared_error(y_test, y_pred)
r2 = r2_score(y_test, y_pred)
print(f"Mean Squared Error: {mse}")
print(f"R-squared: {r2}")
# Out:
# Mean Squared Error: 169555.4447716349
# R-squared: 0.5275857184287512

# %%
from sklearn.metrics import mean_squared_error
import numpy as np
mse=181797.17303985986
rmse = np.sqrt(mse)
rmse
# Out:
# 426.3767970233135

# %%
variable_selection_rmse["PCR"]=rmse
variable_selection_rmse
# Out:
# {'KNN': 270.4950501185793, 'PCR': 426.3767970233135}

# %%
variable_selection_rsq["PCR"]=r2
variable_selection_rsq
# Out:
# {'KNN': 0.7961409846038952, 'PCR': 0.5275857184287512}

# %% [markdown]
# #Partial Least Squares Regression (PLSR)

# %%
import numpy as np
import pandas as pd
from sklearn.cross_decomposition import PLSRegression
from sklearn.metrics import mean_squared_error,r2_score
from sklearn.model_selection import train_test_split
from sklearn.preprocessing import StandardScaler

# %%
scaler = StandardScaler()
x_scaled = scaler.fit_transform(x)

# %%
pls = PLSRegression(n_components=5)
pls.fit(x_train, y_train)
# Out:
# PLSRegression(n_components=5)

# %%
y_pred = pls.predict(x_test)

# %%
mse = mean_squared_error(y_test, y_pred)
r2 = r2_score(y_test, y_pred)
print(f"Mean Squared Error: {mse}")
print(f"R-squared: {r2}")
# Out:
# Mean Squared Error: 153652.3955080163
# R-squared: 0.5718946912416455

# %%
from sklearn.metrics import mean_squared_error
import numpy as np
mse=153652.3955080163
rmse = np.sqrt(mse)
rmse
# Out:
# 391.9851980726011

# %%
variable_selection_rmse["PLSR"]=rmse
variable_selection_rmse
# Out:
# {'KNN': 270.4950501185793, 'PCR': 426.3767970233135, 'PLSR': 391.9851980726011}

# %%
variable_selection_rsq["PLSR"]=r2
variable_selection_rsq
# Out:
# {'KNN': 0.7961409846038952,
#  'PCR': 0.5275857184287512,
#  'PLSR': 0.5718946912416455}

# %% [markdown]
# #Decision Tree

# %%
import pandas as pd
from sklearn.tree import DecisionTreeRegressor
clf=DecisionTreeRegressor(random_state=42)
clf.fit(x_train,y_train)
clf_pred=clf.predict(x_test)
clf_pred
# Out:
# array([ 357.,    0.,   75., ...,  300.,  135., 2175.])

# %%
from sklearn.metrics import r2_score,mean_squared_error
mse=mean_squared_error(y_test,clf_pred)
mse
# Out:
# 110152.75343361674

# %%
import numpy as np
rmse=np.sqrt(mse)
rmse
# Out:
# 331.8926836096523

# %%
r_sq=r2_score(y_test,clf_pred)
r_sq
# Out:
# 0.6930931121290516

# %%
variable_selection_rmse["Decision Tree"]=rmse
variable_selection_rmse
# Out:
# {'KNN': 270.4950501185793,
#  'PCR': 426.3767970233135,
#  'PLSR': 391.9851980726011,
#  'Decision Tree': 331.8926836096523}

# %%
variable_selection_rsq["Decision Tree"]=r_sq
variable_selection_rsq
# Out:
# {'KNN': 0.7961409846038952,
#  'PCR': 0.5275857184287512,
#  'PLSR': 0.5718946912416455,
#  'Decision Tree': 0.6930931121290516}

# %% [markdown]
# #Random Forest Algorithm

# %%
import pandas as pd
from sklearn.ensemble import RandomForestRegressor
from sklearn.metrics import  r2_score,mean_squared_error

# %%
rf_model=RandomForestRegressor(n_estimators=100,random_state=42)
rf_model.fit(x_train,y_train)
# Out:
# RandomForestRegressor(random_state=42)

# %%
rf_y_pred=rf_model.predict(x_test)
rf_y_pred
# Out:
# array([ 282.94,    0.  ,   97.91, ...,  294.53,  104.88, 1921.75])

# %%
rf_mse=mean_squared_error(y_test,rf_y_pred)
rf_mse
# Out:
# 56111.670109871055

# %%
import numpy as np
rf_rmse=np.sqrt(rf_mse)
rf_rmse
# Out:
# 236.87901998672456

# %%
rf_r_sq=r2_score(y_test,rf_y_pred)
rf_r_sq
# Out:
# 0.8436620283210617

# %%
variable_selection_rmse["Random Forest Algorithm"]=rf_rmse
variable_selection_rmse
# Out:
# {'KNN': 270.4950501185793,
#  'PCR': 426.3767970233135,
#  'PLSR': 391.9851980726011,
#  'Decision Tree': 331.8926836096523,
#  'Random Forest Algorithm': 236.87901998672456}

# %%
variable_selection_rsq["Random Forest Algorithm"]=rf_r_sq
variable_selection_rsq
# Out:
# {'KNN': 0.7961409846038952,
#  'PCR': 0.5275857184287512,
#  'PLSR': 0.5718946912416455,
#  'Decision Tree': 0.6930931121290516,
#  'Random Forest Algorithm': 0.8436620283210617}

# %% [markdown]
# #Linear regression

# %%
from sklearn.linear_model import LinearRegression
model=LinearRegression()
model.fit(x_train,y_train)
from sklearn.metrics import mean_squared_error,r2_score
y_pred=model.predict(x_test)
y_pred
mse=mean_squared_error(y_test,y_pred)
mse
import numpy as np
rmse=np.sqrt(mse)
rmse
r2=r2_score(y_test,y_pred)
r2
# Out:
# 0.5719554071620724

# %%
variable_selection_rmse["Linear regression"]=rmse
variable_selection_rmse
# Out:
# {'KNN': 270.4950501185793,
#  'PCR': 426.3767970233135,
#  'PLSR': 391.9851980726011,
#  'Decision Tree': 331.8926836096523,
#  'Random Forest Algorithm': 236.87901998672456,
#  'Linear regression': 391.9574004892546}

# %%
variable_selection_rsq["Linear regression"]=r2
variable_selection_rsq
# Out:
# {'KNN': 0.7961409846038952,
#  'PCR': 0.5275857184287512,
#  'PLSR': 0.5718946912416455,
#  'Decision Tree': 0.6930931121290516,
#  'Random Forest Algorithm': 0.8436620283210617,
#  'Linear regression': 0.5719554071620724}

# %% [markdown]
# #Ridge regression

# %%
from sklearn.metrics import mean_absolute_error, mean_squared_error, r2_score
from sklearn.linear_model import Ridge
r_model=model.fit(x_train, y_train)
r_model
# Out:
# LinearRegression()

# %%
y_pred = r_model.predict(x_test)
y_pred
# Out:
# array([ 423.44645269,  442.57552714,  389.27077035, ...,  626.29550141,
#          77.10082937, 1154.88058027])

# %%
mse = mean_absolute_error(y_test, y_pred)
mse = mean_squared_error(y_test, y_pred)
rmse = mse ** 0.5
rmse
# Out:
# 391.9574004892546

# %%
r2 = r2_score(y_test, y_pred)
r2
# Out:
# 0.5719554071620724

# %%
variable_selection_rmse["Ridge regression"]=rmse
variable_selection_rmse
# Out:
# {'KNN': 270.4950501185793,
#  'PCR': 426.3767970233135,
#  'PLSR': 391.9851980726011,
#  'Decision Tree': 331.8926836096523,
#  'Random Forest Algorithm': 236.87901998672456,
#  'Linear regression': 391.9574004892546,
#  'Ridge regression': 391.9574004892546}

# %%
variable_selection_rsq["Ridge regression"]=r2
variable_selection_rsq
# Out:
# {'KNN': 0.7961409846038952,
#  'PCR': 0.5275857184287512,
#  'PLSR': 0.5718946912416455,
#  'Decision Tree': 0.6930931121290516,
#  'Random Forest Algorithm': 0.8436620283210617,
#  'Linear regression': 0.5719554071620724,
#  'Ridge regression': 0.5719554071620724}

# %% [markdown]
# #Elastic Net

# %%
from sklearn.linear_model import ElasticNet
elastic_net=ElasticNet(alpha=1.0,l1_ratio=0.5,random_state=42)
elastic_net.fit(x_train,y_train)
y_pred=elastic_net.predict(x_test)
y_pred
mse=mean_squared_error(y_test,y_pred)
mse
rmse=np.sqrt(mse)
rmse
r2=r2_score(y_test,y_pred)
r2
# Out:
# 0.5052266732265012

# %%
variable_selection_rmse["Elastic Net"]=rmse
variable_selection_rmse
# Out:
# {'KNN': 270.4950501185793,
#  'PCR': 426.3767970233135,
#  'PLSR': 391.9851980726011,
#  'Decision Tree': 331.8926836096523,
#  'Random Forest Algorithm': 236.87901998672456,
#  'Linear regression': 391.9574004892546,
#  'Ridge regression': 391.9574004892546,
#  'Elastic Net': 421.402881024321}

# %%
variable_selection_rsq["Elastic Net"]=r2
variable_selection_rsq
# Out:
# {'KNN': 0.7961409846038952,
#  'PCR': 0.5275857184287512,
#  'PLSR': 0.5718946912416455,
#  'Decision Tree': 0.6930931121290516,
#  'Random Forest Algorithm': 0.8436620283210617,
#  'Linear regression': 0.5719554071620724,
#  'Ridge regression': 0.5719554071620724,
#  'Elastic Net': 0.5052266732265012}

# %% [markdown]
# #Support vector Regressor

# %%
from sklearn.svm import SVR
svr=SVR(kernel='rbf',C=100,gamma=0.1,epsilon=0.1)
scaler=StandardScaler()
x_train_scaled=scaler.fit_transform(x_train)
x_test_scaled=scaler.transform(x_test)
svr.fit(x_train_scaled,y_train)
# Out:
# SVR(C=100, gamma=0.1)

# %%
y_pred=svr.predict(x_test_scaled)
y_pred
# Out:
# array([ 231.22264938,    1.61619342,  206.84227628, ...,  375.72626957,
#         124.3946991 , 1343.94534041])

# %%
mse=mean_squared_error(y_test,y_pred)
mse
# Out:
# 110393.14779855446

# %%
rmse=np.sqrt(mse)
rmse
# Out:
# 332.25464300526255

# %%
from sklearn.metrics import mean_squared_error, r2_score
rsq=r2_score(y_test,y_pred)
rsq
# Out:
# 0.6924233269071214

# %%
variable_selection_rmse["Support vector Regressor"]=rmse
variable_selection_rmse
# Out:
# {'KNN': 270.4950501185793,
#  'PCR': 426.3767970233135,
#  'PLSR': 391.9851980726011,
#  'Decision Tree': 331.8926836096523,
#  'Random Forest Algorithm': 236.87901998672456,
#  'Linear regression': 391.9574004892546,
#  'Ridge regression': 391.9574004892546,
#  'Elastic Net': 421.402881024321,
#  'Support vector Regressor': 332.25464300526255}

# %%
variable_selection_rsq["Support vector Regressor"]=rsq
variable_selection_rsq
# Out:
# {'KNN': 0.7961409846038952,
#  'PCR': 0.5275857184287512,
#  'PLSR': 0.5718946912416455,
#  'Decision Tree': 0.6930931121290516,
#  'Random Forest Algorithm': 0.8436620283210617,
#  'Linear regression': 0.5719554071620724,
#  'Ridge regression': 0.5719554071620724,
#  'Elastic Net': 0.5052266732265012,
#  'Support vector Regressor': 0.6924233269071214}

# %% [markdown]
# #Gradient Boosting

# %%
from sklearn.ensemble import GradientBoostingRegressor
from sklearn.metrics import mean_squared_error,r2_score
gbm=GradientBoostingRegressor(n_estimators=100,learning_rate=0.1,max_depth=3,random_state=42)
gbm.fit(x_train,y_train)
# Out:
# GradientBoostingRegressor(random_state=42)

# %%
gbm_y_pred=gbm.predict(x_test)
gbm_y_pred
# Out:
# array([ 283.34670007,  124.78484442,  134.6508442 , ...,  286.88368722,
#          41.19440436, 1668.88740071])

# %%
mse=mean_squared_error(y_test,gbm_y_pred)
mse
# Out:
# 61760.77451389548

# %%
import numpy as np
rmse=np.sqrt(mse)
rmse
# Out:
# 248.51715134753874

# %%
r2=r2_score(y_test,gbm_y_pred)
r2
# Out:
# 0.8279225302345065

# %%
variable_selection_rmse["Gradient Boosting"]=rmse
variable_selection_rmse
# Out:
# {'KNN': 270.4950501185793,
#  'PCR': 426.3767970233135,
#  'PLSR': 391.9851980726011,
#  'Decision Tree': 331.8926836096523,
#  'Random Forest Algorithm': 236.87901998672456,
#  'Linear regression': 391.9574004892546,
#  'Ridge regression': 391.9574004892546,
#  'Elastic Net': 421.402881024321,
#  'Support vector Regressor': 332.25464300526255,
#  'Gradient Boosting': 248.51715134753874}

# %%
variable_selection_rsq["Gradient Boosting"]=r2
variable_selection_rsq
# Out:
# {'KNN': 0.7961409846038952,
#  'PCR': 0.5275857184287512,
#  'PLSR': 0.5718946912416455,
#  'Decision Tree': 0.6930931121290516,
#  'Random Forest Algorithm': 0.8436620283210617,
#  'Linear regression': 0.5719554071620724,
#  'Ridge regression': 0.5719554071620724,
#  'Elastic Net': 0.5052266732265012,
#  'Support vector Regressor': 0.6924233269071214,
#  'Gradient Boosting': 0.8279225302345065}

# %%
import pandas as pd
import seaborn as sns
import matplotlib.pyplot as plt

# %% [markdown]
# model={"model":['KNN','PCR','PLSR','Decision Tree','Random Forest Algorithm','Linear regression','Ridge regression','Elastic Net','Support vector Regressor','Gradient Boosting']}

# %%
df_rmse=pd.DataFrame(list(variable_selection_rmse.items()),columns=['model','variable_selection_rmse'])
df_rmse
# Out:
#                       model  variable_selection_rmse
# 0                       KNN               270.495050
# 1                       PCR               426.376797
# 2                      PLSR               391.985198
# 3             Decision Tree               331.892684
# 4   Random Forest Algorithm               236.879020
# 5         Linear regression               391.957400
# 6          Ridge regression               391.957400
# 7               Elastic Net               421.402881
# 8  Support vector Regressor               332.254643
# 9         Gradient Boosting               248.517151

# %%
df_rsq=pd.DataFrame(list(variable_selection_rsq.items()),columns=['model','variable_selection_rsq'])
df_rsq
# Out:
#                       model  variable_selection_rsq
# 0                       KNN                0.796141
# 1                       PCR                0.527586
# 2                      PLSR                0.571895
# 3             Decision Tree                0.693093
# 4   Random Forest Algorithm                0.843662
# 5         Linear regression                0.571955
# 6          Ridge regression                0.571955
# 7               Elastic Net                0.505227
# 8  Support vector Regressor                0.692423
# 9         Gradient Boosting                0.827923

# %% [markdown]
# #Before grid search

# %%
df1_rmse
# Out:
#                     model  bfgrid_rmse
# 0                     KNN   299.403080
# 1                     PCR   426.376797
# 2                    PLSR   387.103987
# 3       Gradient Boosting   242.395665
# 4           Decision Tree   314.457892
# 5           Random Forest   215.556167
# 6       Linear regression   387.030041
# 7        Ridge regression   387.030041
# 8  Elastic net regression   409.132161
# 9                     SVR   322.029401

# %%
df1_rsq
# Out:
#                     model  bfgrid_rsq
# 0                     KNN    0.750239
# 1                     PCR    0.554715
# 2                    PLSR    0.583262
# 3       Gradient Boosting    0.836295
# 4           Decision Tree    0.724491
# 5           Random Forest    0.870541
# 6       Linear regression    0.582650
# 7        Ridge regression    0.582650
# 8  Elastic net regression    0.533622
# 9                     SVR    0.711064

# %% [markdown]
# #After Gride search

# %%
df2_rmse
# Out:
#                model  afgrid_rmse
# 0                KNN   276.605855
# 1                PCR   426.376797
# 2               PLSR   387.103987
# 3  Gradient Boosting   209.158092
# 4      Decision Tree   265.284961
# 5      Random Forest   213.138482
# 6  Linear regression   387.030041
# 7   Ridge regression   387.030041
# 8                SVR   327.951522
# 9        Elastic Net   386.725519

# %%
df2_rsq
# Out:
#                model  afgrid_rsq
# 0                KNN    0.786826
# 1                PCR    0.582650
# 2               PLSR    0.583897
# 3  Gradient Boosting    0.878112
# 4      Decision Tree    0.803919
# 5      Random Forest    0.873429
# 6  Linear regression    0.582650
# 7   Ridge regression    0.582650
# 8                SVR    0.700339
# 9        Elastic Net    0.583306

# %% [markdown]
# #After Variable selection

# %%
df_rmse
# Out:
#                       model  variable_selection_rmse
# 0                       KNN               270.495050
# 1                       PCR               426.376797
# 2                      PLSR               391.985198
# 3             Decision Tree               331.892684
# 4   Random Forest Algorithm               236.879020
# 5         Linear regression               391.957400
# 6          Ridge regression               391.957400
# 7               Elastic Net               421.402881
# 8  Support vector Regressor               332.254643
# 9         Gradient Boosting               248.517151

# %%
df_rsq
# Out:
#                       model  variable_selection_rsq
# 0                       KNN                0.796141
# 1                       PCR                0.527586
# 2                      PLSR                0.571895
# 3             Decision Tree                0.693093
# 4   Random Forest Algorithm                0.843662
# 5         Linear regression                0.571955
# 6          Ridge regression                0.571955
# 7               Elastic Net                0.505227
# 8  Support vector Regressor                0.692423
# 9         Gradient Boosting                0.827923

# %%
sns.barplot(x='model',y='variable_selection_rmse',data=df_rmse,palette='viridis')
plt.xticks(rotation=90)
plt.show()

# %%
sns.barplot(x='model',y='variable_selection_rsq',data=df_rsq,palette='viridis')
plt.xticks(rotation=90)
plt.show()

# %%
import pandas as pd
import matplotlib.pyplot as plt
data_afgrid_rsq = {
    'model': ['KNN', 'PCR', 'PLSR', 'Gradient Boosting', 'Decision Tree', 'Random Forest', 'Linear regression', 'Ridge regression', 'SVR', 'Elastic Net'],
    'afgrid_rsq': [0.786826, 0.582650, 0.583897, 0.878112, 0.803919, 0.873429, 0.582650, 0.582650, 0.700339, 0.583306]
}
data_bfgrid_rsq = {
    'model': ['KNN', 'PCR', 'PLSR', 'Gradient Boosting', 'Decision Tree', 'Random Forest', 'Linear regression', 'Ridge regression', 'SVR','Elastic net'],
    'bfgrid_rsq': [0.750239, 0.554715, 0.583262, 0.836295, 0.724491, 0.870541, 0.582650, 0.582650, 0.533622, 0.711064]
}
df_afgrid_rsq = pd.DataFrame(data_afgrid_rsq)
df_bfgrid_rsq = pd.DataFrame(data_bfgrid_rsq)
df_combined = pd.merge(df_afgrid_rsq, df_bfgrid_rsq, on='model', how='outer')
fig, ax = plt.subplots(figsize=(12, 6))
bar_width = 0.35
index = range(len(df_combined))
bar1 = plt.bar(index, df_combined['afgrid_rsq'], bar_width, label='afgrid_rsq', color='b')
bar2 = plt.bar([i + bar_width for i in index], df_combined['bfgrid_rsq'], bar_width, label='bfgrid_rsq',color='r')
plt.xlabel('Model')
plt.ylabel('R^2')
plt.title('Comparison of R^2 values for afgrid_rsq and bfgrid_rsq')
plt.xticks([i + bar_width / 2 for i in index], df_combined['model'],rotation=45)
plt.legend()
plt.tight_layout()
plt.show()

# %% [markdown]
# #Interpretation:The graph demonstrates that the models, such as Gradient Boosting and Random Forest, show improved R² values
# after grid search, indicating effective parameter. However, some models like SVR show a slight decrease, underscoring the need for careful
# hyperparameter selection and validation.

# %% [markdown]
# # Project Interpretation

# %% [markdown]
# The average number of rented bikes is higher in the summer season, both on holidays and non-holidays. The average number of rented bikes is higher at
# 18 hr on non-holidays. Additionally, as the temperature increases, the average number of rented bikes also increases, while as humidity increases, the
# average number of rented bikes decreases. The average number of rented bikes is highest in June and July.
# The most important variables for bike sharing demand prediction are Hour, Temperature,Functioning day,Solar Radiation,Humidity, and Season. Random
# forest and Gradient Boosting algorithms are the best models for predicting bike sharing demand.
